# %% [markdown]
# - authors: Eric Kernfeld, Macrina Lobo

# %%
# Set up namespace
setwd("~/Dropbox/FINAL_CO/")
library("ggplot2")
library("magrittr")
library("Seurat")
library("dplyr")
results_path = "erics_code_network_analysis"
dir.create(results_path)
# Load relevant RNA data
dge = readRDS("~/Dropbox/pharynx_celloracle/objects/roadmap/RoadmapSeurat3.rds") %>% UpdateSeuratObject()
dge_pouch = readRDS("~/Dropbox/pharynx_celloracle/objects/roadmap/pouch_object.Rdata") %>% UpdateSeuratObject()
pg = VariableFeatures(dge)
fig1_colors = read.csv("~/Dropbox/pharynx_celloracle/objects/roadmap/roadmap_colors.csv", stringsAsFactors = F)
fig1_colors = setNames(fig1_colors$colour, fig1_colors$cell_type)
expression_by_cluster = Seurat::AverageExpression((dge))
# Load filtered networks from CO
filtered_network_files = "filtered_GRN_10k_0701_2021" %>% list.files(full = T)
names(filtered_network_files) = basename(filtered_network_files) %>% gsub(".csv$", "", .)
cell_type_networks = lapply(filtered_network_files, read.csv, header = T, stringsAsFactors = F, row.names = 1)
cell_type_networks = cell_type_networks[order(as.numeric(names(cell_type_networks)))]
for(cc in names(cell_type_networks)){
  cell_type_networks[[cc]][["cluster"]] = cc
}
# short detour: log the Foxn1 targets
foxn1_targets = cell_type_networks %>% lapply(subset, source=="Foxn1", select = c("target"), drop = T) %>% Reduce(f = union)
write.csv(foxn1_targets, "foxn1_direct_targets.csv")
# Properties of each network: degree distribution and edge weight distribution
# degree (outdegree by default; for in, set source_or_target = "target")
get_degree = function(X, eligible_genes = pg, source_or_target = "source"){
  if(length(eligible_genes)>0){
    X %<>% subset(target %in% pg) 
  } 
  X[c("target", "cluster")] %>% table %>% as.data.frame() %>% set_colnames(c("gene", "cluster", "degree"))
}
outdegree = cell_type_networks %>% lapply(get_degree, eligible_genes = NULL, source_or_target = "target") 
outdegree %<>% Reduce(f = rbind)
dim(outdegree)
head(outdegree)
outdegree_order = outdegree %>% 
  group_by(cluster) %>%
  summarize(median_degree = median(degree)) %>%
  arrange(median_degree)
outdegree$cluster %<>% factor(outdegree_order$cluster)
ggplot(outdegree) + 
  geom_violin(aes(y = degree, x = cluster))

# %%
ggsave("erics_code_network_analysis/indegree.pdf", width = 6, height = 2)
# edge weight
edge_weight_order = cell_type_networks %>% 
  lapply(extract, c("coef_mean", "cluster")) %>%
  Reduce(f = rbind) %>% 
  group_by(cluster) %>%
  summarize(median_absolute_edge_weight = median(abs(coef_mean))) %>%
  arrange(median_absolute_edge_weight)
cell_type_networks %>% 
  lapply(extract, c("coef_mean", "cluster")) %>% 
  Reduce(f = rbind) %>%
  mutate(cluster = cluster %>% factor(levels = edge_weight_order$cluster)) %>%
  ggplot() + 
  geom_violin(aes(y = coef_mean, x = cluster)) + 
  scale_y_continuous(
    trans = scales::trans_new(
      name = "signed_log",
      transform = function(x) sign(x)*log2(abs(x)),
      inverse   = function(x) sign(x)*2^(abs(x))
    ), 
    breaks = c(1, 2, 5, 10, 20, 50, 100, 200) %o% c(-1, 1) %>% c %>% sort
  )
ggsave("erics_code_network_analysis/edge_weight.pdf", width = 6, height = 2)


# How much do the networks have in common?
get_common_links = function(net1, net2){
  net1 %<>% mutate(std = paste(source, target, sign(coef_mean), sep = "__"))
  net2 %<>% mutate(std = paste(source, target, sign(coef_mean), sep = "__"))
  length(intersect(net1$std, net2$std))
}
overlaps = matrix(0, nrow = 28, ncol = 28)
for(i in seq_along(cell_type_networks)){
  for(j in seq_along(cell_type_networks)){
    if(j>=i){next}
    overlaps[i, j] = get_common_links(cell_type_networks[[i]], cell_type_networks[[j]])
  }
}
overlaps = overlaps + t(overlaps)
cluster_order = seriation::seriate(as.dist(exp(-overlaps/3e4))) %>% (seriation::get_order) %>% extract(names(cell_type_networks), .) 
overlaps_long = overlaps %>%
  reshape2::melt() %>% 
  mutate(net1 = names(cell_type_networks)[Var1] %>% factor(levels = cluster_order), 
         net2 = names(cell_type_networks)[Var2] %>% factor(levels = cluster_order),
         overlap = value) 
ggplot(overlaps_long) + 
  geom_tile(aes(x = net1, y = net2, fill = overlap/3e4) ) + 
  scale_fill_viridis_c(option = "viridis", name = "Proportion matching\n(source, target, and\ndirection)") + 
  cowplot::theme_cowplot() + 
  theme(axis.text.x = element_text(angle  = 90, hjust = 1, vjust = 0.5)) + 
  ggtitle("Overlap between cell type-specific networks") + 
  coord_fixed() + 
  ggsave("erics_code_network_analysis/subnet_overlap.pdf", width = 6, height = 6)

# %%
# Choose top regulators by cluster using the CellOracle scores
scores = read.csv("scores_unnormalized.csv", stringsAsFactors = F)
colnames(scores)[[1]] = "gene"
# quick detour: thymus vs parathyroid
scores_wide = scores %>%
  subset(cluster %in% c(4, 26)) %>% 
  tidyr::pivot_wider(id_cols = "gene", names_from = "cluster", values_from = "degree_centrality_out") 
ggplot(scores_wide, mapping = aes(x = `4`, y = `26`, label = gene))  +
  geom_point() + 
  ggrepel::geom_text_repel(data = scores_wide %>% subset(abs(`4`-`26`)>0.05)) + 
  ggtitle("Thymus vs parathyroid") + 
  ggsave("erics_code_network_analysis/Thymus vs parathyroid.pdf", width = 5, height = 5)
# proceed

# %% [markdown]
# - fix Nkx2-1

# %%
library(stringr)

# %%
new_var = c()
for (entry in rownames(expression_by_cluster$RNA)){
    new_var = c(new_var,str_replace(entry,'\\.','-'))}

# %%
new_var
# Out:
#     [1] "Xkr4"             "Gm1992"           "Gm37381"
#     [4] "Rp1"              "Rp1-1"            "Sox17"
#     [7] "Gm37323"          "Mrpl15"           "Lypla1"
#    [10] "Gm37988"          "Tcea1"            "Rgs20"
#    [13] "Gm16041"          "Atp6v1h"          "Oprk1"
#    [16] "Npbwr1"           "Rb1cc1"           "X4732440D04Rik"
#    [19] "Fam150a"          "St18"             "Pcmtd1"
#    [22] "Gm26901"          "Gm30414"          "Sntg1"
#    [25] "Rrs1"             "Adhfe1"           "X3110035E14Rik"
#    [28] "Gm29520"          "Mybl1"            "Vcpip1"
#    [31] "X1700034P13Rik"   "Sgk3"             "Mcmdc2"
#    [34] "Snhg6"            "Tcf24"            "Ppp1r42"
#    [37] "Gm15818"          "Cops5"            "Cspp1"
#    [40] "Arfgef1"          "Cpa6"             "Prex2"
#    [43] "A830018L16Rik"    "Gm17644"          "Gm29663"
#    [46] "Sulf1"            "Slco5a1"          "Gm29283"
#    [49] "Prdm14"           "Ncoa2"            "Gm29570"
#    [52] "Tram1"            "Lactb2"           "Xkr9"
#    [55] "Eya1"             "Gm9947"           "Msc"
#    [58] "Trpa1"            "Kcnb2"            "Terf1"
#    [61] "Sbspon"           "X4930444P10Rik"   "Rpl7"
#    [64] "Rdh10"            "Gm28095"          "Stau2"
#    [67] "Gm7568"           "Ube2w"            "Tceb1"
#    [70] "D030040B21Rik"    "Tmem70"           "Ly96"
#    [73] "Gm28376"          "Jph1"             "Gm28783"
#    [76] "Gdap1"            "Gm28784"          "Pi15"
#    [79] "Gm28154"          "Gm16070"          "Crispld1"
#    [82] "Gm28153"          "Crisp4"           "Defb18"
#    [85] "Defb41"           "Gm29006"          "Gm15825"
#    [88] "Tfap2d"           "Tfap2b"           "Gm28340"
#    [91] "Pkhd1"            "X4930486I03Rik"   "Gm28653"
#    [94] "Il17a"            "Il17f"            "Mcm3"
#    [97] "Gm28065"          "X6720483E21Rik"   "Paqr8"
#   [100] "Efhc1"            "Tram2"            "Gm28287"
#   [103] "Tmem14a"          "Gsta3"            "Gm28836"
#   [106] "Khdc1a"           "Khdc1c"           "Khdc1b"
#   [109] "Kcnq5"            "Gm26580"          "Rims1"
#   [112] "X4933415F23Rik"   "Gm27028"          "Gm29107"
#   [115] "Ogfrl1"           "Gm28822"          "B3gat2"
#   [118] "Smap1"            "Sdhaf4"           "Fam135a"
#   [121] "Col9a1"           "Col19a1"          "Lmbrd1"
#   [124] "Gm28237"          "Gm29414"          "Adgrb3"
#   [127] "X4931408C20Rik"   "Gm5524"           "Gm597"
#   [130] "Gm9898"           "Phf3"             "Ptp4a1"
#   [133] "Gm29669"          "Gm28644"          "X4931428L18Rik"
#   [136] "Gm29128"          "Lgsn"             "Pih1d3"
#   [139] "Khdrbs2"          "Gm5415"           "Gm37724"
#   [142] "Gm37591"          "Prim2"            "Rab23"
#   [145] "Bag2"             "Zfp451"           "Bend6"
#   [148] "Dst"              "Gm37958"          "Gm37233"
#   [151] "Ccdc115"          "Gm28306"          "Imp4"
#   [154] "Ptpn18"           "X4930568A12Rik"   "Prss39"
#   [157] "Cfc1"             "Prss40"           "X1700101I19Rik"
#   [160] "Amer3"            "Arhgef4"          "Gm38336"
#   [163] "Fam168b"          "Plekhb2"          "Gm37068"
#   [166] "Gm28415"          "X1110002O04Rik"   "Gm37146"
#   [169] "Gm33222"          "X4930535G08Rik"   "Hs6st1"
#   [172] "Gm37335"          "Gm33280"          "Uggt1"
#   [175] "Neurl3"           "Arid5a"           "X4930403P22Rik"
#   [178] "Kansl3"           "Fer1l5"           "Lman2l"
#   [181] "Cnnm4"            "Cnnm3"            "Gm38033"
#   [184] "Ankrd23"          "Gm43543"          "Ankrd39"
#   [187] "Sema4c"           "Fam178b"          "Cox5b"
#   [190] "Actr1b"           "X4933424G06Rik"   "Gm33533"
#   [193] "Zap70"            "Tmem131"          "Vwa3b"
#   [196] "Gm37020"          "Cnga3"            "Inpp4a"
#   [199] "X4930439A04Rik"   "Coa5"             "Unc50"
#   [202] "Mgat4a"           "X2010300C02Rik"   "X4930556I23Rik"
#   [205] "Tsga10"           "Gm26805"          "Lipt1"
#   [208] "Mitd1"            "Mrpl30"           "Lyg2"
#   [211] "Gm15457"          "Lyg1"             "Txndc9"
#   [214] "Eif5b"            "Rev1"             "Gm5099"
#   [217] "Aff3"             "Gm16150"          "Gm16151"
#   [220] "Gm16152"          "Lonrf2"           "Chst10"
#   [223] "Gm37707"          "Nms"              "Pdcl3"
#   [226] "Gm37821"          "Npas2"            "Rpl31"
#   [229] "Tbc1d8"           "Cnot11"           "Rnf149"
#   [232] "Creg2"            "D930019O06Rik"    "Rfx8"
#   [235] "Gm3646"           "X1700066B17Rik"   "Map4k4"
#   [238] "Il1r2"            "Gm16894"          "Il1r1"
#   [241] "Il1rl2"           "Il1rl1"           "Il18r1"
#   [244] "Il18rap"          "Gm35801"          "Slc9a4"
#   [247] "Slc9a2"           "Gm37623"          "Gm37915"
#   [250] "Mfsd9"            "Tmem182"          "X4930448I06Rik"
#   [253] "Gm28634"          "Gm29260"          "Gm9915"
#   [256] "Gm29664"          "Gm28175"          "Gm28140"
#   [259] "Pantr1"           "Pou3f3"           "Dalir"
#   [262] "Mrps9"            "Gpr45"            "Tgfbrap1"
#   [265] "Gm28782"          "X8430432A02Rik"   "AI597479"
#   [268] "Fhl2"             "Gm29040"          "Nck2"
#   [271] "X1500015O10Rik"   "Gm29155"          "Gm29157"
#   [274] "Gm29156"          "Uxs1"             "Tpp2"
#   [277] "Mettl21c"         "Gm8251"           "Tex30"
#   [280] "Kdelc1"           "Bivm"             "Ercc5"
#   [283] "Mettl21e"         "Gulp1"            "X4930521E06Rik"
#   [286] "Col3a1"           "Col5a2"           "Wdr75"
#   [289] "Gm5269"           "Slc40a1"          "Dnah7b"
#   [292] "Dnah7c"           "Slc39a10"         "Gm28151"
#   [295] "Gm28826"          "C230029F24Rik"    "X4933411E06Rik"
#   [298] "Gm29665"          "Gm28321"          "Tmeff2"
#   [301] "Gm28322"          "Gm28319"          "Gm29325"
#   [304] "X9330175M20Rik"   "Sdpr"             "X1700072G22Rik"
#   [307] "Nabp1"            "Gm17767"          "Gm28055"
#   [310] "Myo1b"            "Stat4"            "Stat1"
#   [313] "Gls"              "Nab1"             "Gm553"
#   [316] "Gm28178"          "Tmem194b"         "Mfsd6"
#   [319] "Inpp1"            "Hibch"            "X1700019D03Rik"
#   [322] "Mstn"             "X1700019A02Rik"   "Pms1"
#   [325] "Gm28777"          "Ormdl1"           "Gm28778"
#   [328] "Osgepl1"          "Gm28551"          "Asnsd1"
#   [331] "Dnah7a"           "Stk17b"           "Hecw2"
#   [334] "Ccdc150"          "Gtf3c3"           "Pgap1"
#   [337] "Ankrd44"          "X4930444A19Rik"   "Sf3b1"
#   [340] "Coq10b"           "Hspd1"            "Hspe1"
#   [343] "Mob4"             "Rftn2"            "Gm10561"
#   [346] "Mars2"            "Boll"             "Plcl1"
#   [349] "X9130227L01Rik"   "X1700003I22Rik"   "Gm28240"
#   [352] "Hsfy2"            "Satb2"            "X1700126A01Rik"
#   [355] "BC055402"         "X4930558J18Rik"   "X1700066M21Rik"
#   [358] "Tyw5"             "X9430016H08Rik"   "Spats2l"
#   [361] "Gm17234"          "Kctd18"           "Sgol2a"
#   [364] "Aox1"             "Aox3"             "Aox4"
#   [367] "Gm15759"          "Aox2"             "Bzw1"
#   [370] "Clk1"             "Ppil3"            "Nif3l1"
#   [373] "Orc2"             "Gm15834"          "Fam126b"
#   [376] "Ndufb3"           "Als2cr12"         "Cflar"
#   [379] "Casp8"            "Trak2"            "Stradb"
#   [382] "Gm29018"          "Als2cr11"         "Tmem237"
#   [385] "G730003C15Rik"    "Mpp4"             "Gm29017"
#   [388] "Als2"             "Cdk15"            "Gm29016"
#   [391] "Fzd7"             "Gm26813"          "Gm973"
#   [394] "Gm28411"          "X1700122D07Rik"   "Sumo1"
#   [397] "Nop58"            "Bmpr2"            "Fam117b"
#   [400] "Ica1l"            "Wdr12"            "Carf"
#   [403] "Nbeal1"           "Cyp20a1"          "Abi2"
#   [406] "Raph1"            "Cd28"             "Gm11579"
#   [409] "X2310016D23Rik"   "Ctla4"            "Icos"
#   [412] "Gm28083"          "Gm11587"          "X9530026F06Rik"
#   [415] "Gm11588"          "Gm28449"          "X4930587A21Rik"
#   [418] "Pard3b"           "Pard3bos1"        "Pard3bos2"
#   [421] "Pard3bos3"        "Gm29084"          "Nrp2"
#   [424] "Gm29083"          "Gm4208"           "Ino80d"
#   [427] "Ino80dos"         "Gm20342"          "Ndufs1"
#   [430] "Eef1b2"           "Gpr1"             "Gm11608"
#   [433] "Zdbf2"            "Adam23"           "Dytn"
#   [436] "Mdh1b"            "Fastkd2"          "X4933402D24Rik"
#   [439] "Gm13749"          "Klf7"             "Gm26649"
#   [442] "Gm13748"          "Gm28981"          "Creb1"
#   [445] "Mettl21a"         "Gm28982"          "Gm29152"
#   [448] "Ccnyl1"           "Fzd5"             "Plekhm3"
#   [451] "Akr1cl"           "Cryge"            "Crygd"
#   [454] "Crygc"            "Crygb"            "Cryga"
#   [457] "Gm28845"          "D630023F18Rik"    "Idh1"
#   [460] "Pikfyve"          "Pth2r"            "Crygf"
#   [463] "Map2"             "Gm10558"          "Unc80"
#   [466] "Rpe"              "Kansl1l"          "Acadl"
#   [469] "Myl1"             "Lancl1"           "Cps1"
#   [472] "Gm15668"          "Gm15669"          "Gm15671"
#   [475] "Erbb4"            "Gm28497"          "Gm29113"
#   [478] "Gm29114"          "Ikzf2"            "Spag16"
#   [481] "Vwc2l"            "Bard1"            "Abca12"
#   [484] "Atic"             "Fn1"              "Apol7d"
#   [487] "Gm8883"           "Gm28818"          "X4933417E11Rik"
#   [490] "X4930556G22Rik"   "Gm4319"           "Mreg"
#   [493] "D230017M19Rik"    "Pecr"             "Tmem169"
#   [496] "Xrcc5"            "March4"           "Smarcal1"
#   [499] "Ankar"            "Rpl37a"           "Igfbp2"
#   [502] "Igfbp5"           "X1700027A15Rik"   "Tnp1"
#   [505] "Gm29185"          "Pinc"             "D530049I02Rik"
#   [508] "C530043A13Rik"    "Gm29186"          "X6030407O03Rik"
#   [511] "Gm29183"          "Tns1"             "Rufy4"
#   [514] "Cxcr2"            "Cxcr1"            "Arpc2"
#   [517] "Gpbar1"           "Aamp"             "Gm28364"
#   [520] "Pnkd"             "Tmbim1"           "Catip"
#   [523] "Slc11a1"          "Ctdsp1"           "Vil1"
#   [526] "Usp37"            "Rqcd1"            "Plcd4"
#   [529] "Zfp142"           "Bcs1l"            "Rnf25"
#   [532] "Stk36"            "Ttll4"            "Cyp27a1"
#   [535] "Prkag3"           "Wnt6"             "Gm29539"
#   [538] "Wnt10a"           "Cdk5r2"           "Fev"
#   [541] "Cryba2"           "Ccdc108"          "Gm15841"
#   [544] "Ihh"              "Nhej1"            "Slc23a3"
#   [547] "Cnppd1"           "Fam134a"          "Zfand2b"
#   [550] "Abcb6"            "Atg9a"            "Ankzf1"
#   [553] "Glb1l"            "Stk16"            "Tuba4a"
#   [556] "A630095N17Rik"    "Dnajb2"           "Ptprn"
#   [559] "Gm28294"          "Resp18"           "Gm28902"
#   [562] "Dnpep"            "Des"              "Gm15179"
#   [565] "Speg"             "Gm15178"          "Gmppa"
#   [568] "Asic4"            "Chpf"             "Obsl1"
#   [571] "Tmem198"          "Inha"             "Stk11ip"
#   [574] "Slc4a3"           "Gm29065"          "Gm29069"
#   [577] "Gm17751"          "Gm816"            "Epha4"
#   [580] "Gm28386"          "Gm28387"          "Pax3"
#   [583] "Sgpp2"            "Gm28410"          "Farsb"
#   [586] "BC035947"         "Mogat1"           "X5730419F03Rik"
#   [589] "Gm29611"          "Acsl3"            "Utp14b"
#   [592] "Gm29536"          "Kcne4"            "Gm29187"
#   [595] "Scg2"             "Ap1s3"            "Wdfy1"
#   [598] "Mrpl44"           "Serpine2"         "X9830004L10Rik"
#   [601] "Fam124b"          "X2310015K22Rik"   "Cul3"
#   [604] "Gm29125"          "X1700016L21Rik"   "Dock10"
#   [607] "Nyap2"            "Irs1"             "Gm9747"
#   [610] "Rhbdd1"           "Gm28940"          "Col4a4"
#   [613] "Col4a3"           "Mff"              "Tm4sf20"
#   [616] "Gm28942"          "Agfg1"            "Slc19a3"
#   [619] "Krtap28-10"       "Krtap28-13"       "Ccl20"
#   [622] "Daw1"             "Sphkap"           "X4933436I20Rik"
#   [625] "Pid1"             "Dner"             "Trip12"
#   [628] "Fbxo36"           "Slc16a14"         "C130026I21Rik"
#   [631] "A530032D15Rik"    "Gm10553"          "A530040E14Rik"
#   [634] "Gm16028"          "Gm16025"          "Gm16092"
#   [637] "G530012D18Rik"    "Sp110"            "Gm16094"
#   [640] "Sp140"            "Gm10552"          "Gm17017"
#   [643] "Sp100"            "A630001G21Rik"    "X9930111H07Rik"
#   [646] "Cab39"            "Itm2c"            "X4933407L21Rik"
#   [649] "Gm28884"          "Gpr55"            "Gm28100"
#   [652] "Spata3"           "X2810459M11Rik"   "Psmd1"
#   [655] "Htr2b"            "Gm21972"          "Armc9"
#   [658] "Gm16341"          "B3gnt7"           "Gm28626"
#   [661] "Ncl"              "Nmur1"            "X1700019O17Rik"
#   [664] "Ptma"             "Pde6d"            "Cops7b"
#   [667] "Nppc"             "Dis3l2"           "Gm28375"
#   [670] "Gm29371"          "Alppl2"           "Alpi"
#   [673] "Akp3"             "Gm29374"          "Ecel1"
#   [676] "Prss56"           "Chrnd"            "Chrng"
#   [679] "Eif4e2"           "Efhd1"            "Efhd1os"
#   [682] "Gigyf2"           "Kcnj13"           "X3110079O15Rik"
#   [685] "Ngef"             "Neu2"             "Inpp5d"
#   [688] "Atg16l1"          "Sag"              "Dgkd"
#   [691] "Gm19582"          "Usp40"            "Ugt1a10"
#   [694] "Ugt1a9"           "Ugt1a8"           "Ugt1a7c"
#   [697] "Ugt1a6b"          "Ugt1a6a"          "Ugt1a5"
#   [700] "Ugt1a2"           "Dnajb3"           "Ugt1a1"
#   [703] "Mroh2a"           "Hjurp"            "Trpm8"
#   [706] "X4930453O03Rik"   "Spp2"             "Gm29538"
#   [709] "Gm28888"          "Glrp1"            "Gm19589"
#   [712] "Gm29336"          "Arl4c"            "Platr5"
#   [715] "Gm29337"          "X1700067G17Rik"   "Sh3bp4"
#   [718] "Gm28342"          "C030007H22Rik"    "Agap1"
#   [721] "Gbx2"             "Asb18"            "Iqca"
#   [724] "X4930434B07Rik"   "Ackr3"            "Gm28721"
#   [727] "Gm28723"          "Gm28722"          "Cops8"
#   [730] "Gm9991"           "Col6a3"           "Mlph"
#   [733] "Prlh"             "Rab17"            "Gm28199"
#   [736] "Lrrfip1"          "Rbm44"            "Ramp1"
#   [739] "Ube2f"            "Gm26683"          "Scly"
#   [742] "Gm17090"          "Espnl"            "Klhl30"
#   [745] "Fam132b"          "Ilkap"            "X1700020N18Rik"
#   [748] "Hes6"             "Per2"             "Gm28382"
#   [751] "Traf3ip1"         "Asb1"             "Gm28380"
#   [754] "Gm29100"          "Twist2"           "Hdac4"
#   [757] "Gm26720"          "Gm29099"          "Ndufa10"
#   [760] "Olfr1416"         "Olfr1415"         "Olfr1414"
#   [763] "X1700054K02Rik"   "Olfr1413"         "Gm28479"
#   [766] "Olfr1412"         "Olfr1411"         "Olfr1410"
#   [769] "Olfr12"           "Myeov2"           "Otos"
#   [772] "Gm29483"          "Gm29482"          "Gm29481"
#   [775] "Gpc1"             "Gm29480"          "Ankmy1"
#   [778] "Dusp28"           "X5033417F24Rik"   "Rnpepl1"
#   [781] "X9430060I03Rik"   "Capn10"           "Gpr35"
#   [784] "Aqp12"            "Kif1a"            "Gm28086"
#   [787] "Agxt"             "X2310007B03Rik"   "Crocc2"
#   [790] "Sned1"            "Mterf4"           "Gm28535"
#   [793] "Pask"             "Ppp1r7"           "Ano7"
#   [796] "Hdlbp"            "Sept2"            "Farp2"
#   [799] "Stk25"            "Gm28536"          "Bok"
#   [802] "Thap4"            "Gm10550"          "Atg4b"
#   [805] "Dtymk"            "Ing5"             "D2hgdh"
#   [808] "Gal3st2"          "Gm9994"           "Gm6086"
#   [811] "Neu4"             "Pdcd1"            "X4930440C22Rik"
#   [814] "Fam174a"          "St8sia4"          "X4930598F16Rik"
#   [817] "X1700063A18Rik"   "Gm29601"          "X4930533P14Rik"
#   [820] "Slco4c1"          "Panct2"           "Gm28901"
#   [823] "Slco6c1"          "D1Ertd622e"       "Ppip5k2"
#   [826] "Gin1"             "Pam"              "X1810006J02Rik"
#   [829] "Gm29461"          "Slco6d1"          "Gm7967"
#   [832] "Cntnap5b"         "Gm20268"          "Gm28187"
#   [835] "Cdh20"            "Gm15699"          "Gm29012"
#   [838] "Rnf152"           "Gm17634"          "Pign"
#   [841] "X2310035C23Rik"   "Tnfrsf11a"        "Gm7160"
#   [844] "Zcchc2"           "Gm20753"          "Phlpp1"
#   [847] "A530053M12Rik"    "Bcl2"             "D630008O14Rik"
#   [850] "Kdsr"             "Vps4b"            "Serpinb5"
#   [853] "Serpinb12"        "Serpinb13"        "Serpinb3a"
#   [856] "Serpinb3d"        "Serpinb3b"        "Serpinb3c"
#   [859] "Serpinb11"        "Gm15391"          "Serpinb7"
#   [862] "Serpinb2"         "Serpinb10"        "Serpinb8"
#   [865] "Gm15389"          "D830032E09Rik"    "Cdh7"
#   [868] "Cdh19"            "Gm29088"          "Dsel"
#   [871] "Gm28189"          "X9330185C12Rik"   "Cntnap5a"
#   [874] "Gm19965"          "Zfp813-ps"        "Gm28363"
#   [877] "B020011L13Rik"    "Gm28360"          "Gm28168"
#   [880] "Gm7145"           "Gm29106"          "Tsn"
#   [883] "Nifk"             "Gm28867"          "Clasp1"
#   [886] "X2900060B14Rik"   "Tfcp2l1"          "Gli2"
#   [889] "Gm26831"          "Gm29456"          "Gm29455"
#   [892] "Inhbb"            "Ralb"             "Gm27184"
#   [895] "Tmem185b"         "X3830432H09Rik"   "Epb41l5"
#   [898] "Ptpn4"            "Gm28209"          "Tmem177"
#   [901] "Cfap221"          "Sctr"             "Tmem37"
#   [904] "Dbi"              "X3110009E18Rik"   "Steap3"
#   [907] "C1ql2"            "X1700012E03Rik"   "Marco"
#   [910] "En1"              "X2610027F03Rik"   "Gm29346"
#   [913] "Gm29345"          "Gm29348"          "Gm29347"
#   [916] "Celrr"            "Gm29359"          "Insig2"
#   [919] "X2210011K15Rik"   "Ccdc93"           "Gm15392"
#   [922] "Htr5b"            "Ddx18"            "Gm28590"
#   [925] "Dpp10"            "Gm28928"          "X1700121L03Rik"
#   [928] "Actr3"            "Gm28706"          "Slc35f5"
#   [931] "Gpr39"            "Lypd1"            "Nckap5"
#   [934] "X4930599A14Rik"   "Mgat5"            "Tmem163"
#   [937] "Acmsd"            "X2900009J06Rik"   "Ccnt2"
#   [940] "Map3k19"          "Rab3gap1"         "Zranb3"
#   [943] "Gm28800"          "R3hdm1"           "Ubxn4"
#   [946] "Lct"              "Mcm6"             "Dars"
#   [949] "Cxcr4"            "Gm26686"          "Thsd7b"
#   [952] "Gm16081"          "Cd55b"            "Gm15674"
#   [955] "Gm15675"          "Cd55"             "Gm16083"
#   [958] "Zp3r"             "C4bp"             "Gm29427"
#   [961] "Pfkfb2"           "Yod1"             "AA986860"
#   [964] "Gm28857"          "Gm28856"          "Fcamr"
#   [967] "Gm15848"          "Pigr"             "Fcmr"
#   [970] "Il24"             "Il20"             "Il19"
#   [973] "Il10"             "Mapkapk2"         "Dyrk3"
#   [976] "Eif2d"            "Rassf5"           "Ikbke"
#   [979] "Gm28914"          "Gm28913"          "Srgap2"
#   [982] "Fam72a"           "Avpr1b"           "Ctse"
#   [985] "Rab7b"            "Slc26a9"          "Pm20d1"
#   [988] "Slc41a1"          "Rab29"            "Nucks1"
#   [991] "Slc45a3"          "Elk4"             "Mfsd4"
#   [994] "Gm26892"          "Cdk18"            "Gm29629"
#   [997] "Lemd1"            "X1700037F24Rik"   "Gm10188"
#  [1000] "Gm29630"          "Klhdc8a"          "Nuak2"
#  [1003] "F730311O21Rik"    "Tmcc2"            "Gm15849"
#  [1006] "Dstyk"            "Rbbp5"            "Tmem81"
#  [1009] "Cntn2"            "Nfasc"            "Gm10538"
#  [1012] "Lrrn2"            "Mdm4"             "Pik3c2b"
#  [1015] "Gm28609"          "Ppp1r15b"         "Plekha6"
#  [1018] "Gm19461"          "Golt1a"           "Gm28040"
#  [1021] "Kiss1"            "Ren1"             "Etnk2"
#  [1024] "Sox13"            "Snrpe"            "Gm26706"
#  [1027] "Zc3h11a"          "Gm38394"          "Zbed6"
#  [1030] "Lax1"             "Atp2b4"           "Gm28441"
#  [1033] "Optc"             "Gm15851"          "Prelp"
#  [1036] "Gm1627"           "Fmod"             "Btg2"
#  [1039] "Chit1"            "Chil1"            "Mybph"
#  [1042] "Adora1"           "Myog"             "Ppfia4"
#  [1045] "Tmem183a"         "X4933406M09Rik"   "Cyb5r1"
#  [1048] "Adipor1"          "Platr1"           "Klhl12"
#  [1051] "Rabif"            "Mgat4e"           "Kdm5b"
#  [1054] "Gm26783"          "Syt2"             "Ppp1r12b"
#  [1057] "Gm28892"          "Ube2t"            "Lgr6"
#  [1060] "Gm10535"          "Ptpn7"            "Arl8a"
#  [1063] "Gm15445"          "Gpr37l1"          "Gm26642"
#  [1066] "Elf3"             "Rnpep"            "Timm17a"
#  [1069] "Lmod1"            "Shisa4"           "Ipo9"
#  [1072] "Nav1"             "Gm4793"           "Gm38399"
#  [1075] "Csrp1"            "Phlda3"           "Tnni1"
#  [1078] "Lad1"             "Tnnt2"            "Pkp1"
#  [1081] "Igfn1"            "Tmem9"            "Ascl5"
#  [1084] "Cacna1s"          "Gm37759"          "Kif21b"
#  [1087] "Mroh3"            "X5730559C18Rik"   "Gm26568"
#  [1090] "A430034D21Rik"    "Gm37552"          "Gm26781"
#  [1093] "Gpr25"            "Camsap2"          "Ddx59"
#  [1096] "Kif14"            "Gm37799"          "Gm33994"
#  [1099] "X4933409D19Rik"   "Platr23"          "Zfp281"
#  [1102] "Gm19705"          "Platr22"          "Nr5a2"
#  [1105] "Gm26979"          "Gm26936"          "A430106G13Rik"
#  [1108] "Ptprc"            "Gm28556"          "Atp6v1g3"
#  [1111] "Nek7"             "Gm28501"          "Gm5833"
#  [1114] "Lhx9"             "X2310009B15Rik"   "X1700019P21Rik"
#  [1117] "Dennd1b"          "Crb1"             "X4933436E23Rik"
#  [1120] "Gm34816"          "Zbtb41"           "Aspm"
#  [1123] "F13b"             "Cfhr1"            "Gm4788"
#  [1126] "Cfhr2"            "Cfh"              "Kcnt2"
#  [1129] "X4930590L20Rik"   "Cdc73"            "B3galt2"
#  [1132] "Glrx2"            "Trove2"           "Uchl5"
#  [1135] "Rgs2"             "Rgs13"            "Rgs1"
#  [1138] "Rgs21"            "Rgs18"            "Gm29514"
#  [1141] "Brinp3"           "Gm15584"          "Gm29515"
#  [1144] "Gm29020"          "Gm29398"          "Pla2g4a"
#  [1147] "Ptgs2"            "Ptgs2os2"         "Pdc"
#  [1150] "X2310030A07Rik"   "BC003331"         "Tpr"
#  [1153] "Prg4"             "Hmcn1"            "Gm20631"
#  [1156] "Gm29188"          "C730036E19Rik"    "Gm10138"
#  [1159] "Ivns1abp"         "Swt1"             "Trmt1l"
#  [1162] "Rnf2"             "Gm28181"          "Fam129a"
#  [1165] "X2810414N06Rik"   "Edem3"            "X1700025G04Rik"
#  [1168] "Gm28610"          "Tsen15"           "Colgalt2"
#  [1171] "Rgl1"             "Apobec4"          "Arpc5"
#  [1174] "Ncf2"             "Smg7"             "Nmnat2"
#  [1177] "Gm28960"          "Lamc2"            "Lamc1"
#  [1180] "Shcbp1l"          "Dhx9"             "Npl"
#  [1183] "Rgs8"             "Gm29529"          "C230024C17Rik"
#  [1186] "Rgs16"            "Gm28513"          "Rnasel"
#  [1189] "Rgsl1"            "Teddm2"           "Teddm1b"
#  [1192] "Teddm1a"          "Glul"             "Gm29290"
#  [1195] "Gm29291"          "Gm28286"          "A830008E24Rik"
#  [1198] "Zfp648"           "X4930452N14Rik"   "X4930532M18Rik"
#  [1201] "Cacna1e"          "Gm29282"          "Gm9530"
#  [1204] "Ier5"             "Mr1"              "Stx6"
#  [1207] "BC034090"         "Gm37622"          "Xpr1"
#  [1210] "Gm5532"           "Acbd6"            "Lhx4"
#  [1213] "Qsox1"            "Gm37571"          "Cep350"
#  [1216] "Tor1aip1"         "Tor1aip2"         "Fam163a"
#  [1219] "Tdrd5"            "X4930518J20Rik"   "Nphs2"
#  [1222] "Axdnd1"           "Gm2000"           "Soat1"
#  [1225] "Gm10031"          "Abl2"             "Tor3a"
#  [1228] "Fam20b"           "Ralgps2"          "Angptl1"
#  [1231] "X4930439D14Rik"   "Gm28694"          "Tex35"
#  [1234] "Rasal2"           "BC026585"         "Gm15486"
#  [1237] "Sec16b"           "Brinp2"           "Astn1"
#  [1240] "Gm37679"          "Pappa2"           "X1600012P17Rik"
#  [1243] "X4930562F17Rik"   "Rfwd2"            "Tnr"
#  [1246] "Gm38039"          "Gm37294"          "X4930523C07Rik"
#  [1249] "X4930562F07Rik"   "Tnn"              "Mrps14"
#  [1252] "Cacybp"           "Rabgap1l"         "Gm36975"
#  [1255] "Gm37083"          "Gm38060"          "Rc3h1"
#  [1258] "Serpinc1"         "Zbtb37"           "Gm37362"
#  [1261] "Dars2"            "Gm37634"          "Cenpl"
#  [1264] "Klhl20"           "Ankrd45"          "X4930469G21Rik"
#  [1267] "Prdx6"            "Tnfsf4"           "Tnfsf18"
#  [1270] "Fasl"             "Suco"             "Gm31925"
#  [1273] "X4930558K02Rik"   "Pigc"             "Gm38304"
#  [1276] "Dnm3"             "X2810442N19Rik"   "Dnm3os"
#  [1279] "Mettl13"          "Vamp4"            "Myoc"
#  [1282] "X7420461P10Rik"   "Prrc2c"           "Fmo4"
#  [1285] "Fmo1"             "Fmo2"             "Fmo6"
#  [1288] "Fmo3"             "Gm37273"          "Mroh9"
#  [1291] "Prrx1"            "Gm20471"          "Gm26523"
#  [1294] "Gorab"            "Gm29500"          "Mettl11b"
#  [1297] "Kifap3"           "Scyl3"            "BC055324"
#  [1300] "Mettl18"          "Sele"             "Sell"
#  [1303] "Selp"             "Gm16587"          "Gm16548"
#  [1306] "F5"               "Slc19a2"          "Ccdc181"
#  [1309] "Blzf1"            "Nme7"             "Atp1b1"
#  [1312] "Gm32391"          "Gm26685"          "Gm37754"
#  [1315] "Gm37853"          "Gm37184"          "Gm36945"
#  [1318] "Dpt"              "Gm32569"          "Xcl1"
#  [1321] "X1700029M03Rik"   "X4930568G15Rik"   "Tbx19"
#  [1324] "Sft2d2"           "Tiprl"            "Gpr161"
#  [1327] "Dcaf6"            "Mpc2"             "Adcy10"
#  [1330] "Gm38325"          "Mpzl1"            "Rcsd1"
#  [1333] "Gm37073"          "Creg1"            "Gm36972"
#  [1336] "Cd247"            "Gm37469"          "Pou2f1"
#  [1339] "Gm26665"          "Gm37923"          "Dusp27"
#  [1342] "Gpa33"            "Mael"             "Ildr2"
#  [1345] "X5330438I03Rik"   "Gm15853"          "Tada1"
#  [1348] "Gm15853-1"        "Pogk"             "Gm4846"
#  [1351] "Gm4847"           "Fmo9"             "Gm16701"
#  [1354] "Gm16701-1"        "Fam78b"           "Uck2"
#  [1357] "Gm37982"          "Gm2453"           "Tmco1"
#  [1360] "Aldh9a1"          "Mgst3"            "Lrrc52"
#  [1363] "Rxrg"             "Lmx1a"            "Gm20711"
#  [1366] "Pbx1"             "Gm37839"          "Nuf2"
#  [1369] "Rgs5"             "Rgs4"             "Ccdc190"
#  [1372] "Hsd17b7"          "X3110045C21Rik"   "Ddr2"
#  [1375] "Uap1"             "Gm37748"          "Gm37502"
#  [1378] "Uhmk1"            "X4930500M09Rik"   "Sh2d1b2"
#  [1381] "Sh2d1b1"          "Gm7694"           "Nos1ap"
#  [1384] "X1700015E13Rik"   "Olfml2b"          "Atf6"
#  [1387] "Dusp12"           "Gm26620"          "Fcrlb"
#  [1390] "Fcrla"            "Fcgr2b"           "Gm38204"
#  [1393] "Gm10522"          "Fcgr4"            "Fcgr3"
#  [1396] "Cfap126"          "Sdhc"             "Mpz"
#  [1399] "Pcp4l1"           "Nr1i3"            "Tomm40l"
#  [1402] "Apoa2"            "Fcer1g"           "Ndufs2"
#  [1405] "Adamts4"          "B4galt3"          "Ppox"
#  [1408] "Usp21"            "Ufc1"             "Gm20045"
#  [1411] "Dedd"             "Nit1"             "Pfdn2"
#  [1414] "Klhdc9"           "Pvrl4"            "Arhgap30"
#  [1417] "Usf1"             "Tstd1"            "Gm26641"
#  [1420] "F11r"             "B930036N10Rik"    "Alyref2"
#  [1423] "Itln1"            "Cd244"            "Ly9"
#  [1426] "Slamf7"           "Gm37787"          "Cd48"
#  [1429] "Slamf1"           "Cd84"             "Gm10521"
#  [1432] "Gm37065"          "Slamf6"           "Vangl2"
#  [1435] "Nhlh1"            "Ncstn"            "Copa"
#  [1438] "Gm37756"          "Pex19"            "Dcaf8"
#  [1441] "Pea15a"           "Casq1"            "Gm17224"
#  [1444] "Atp1a4"           "Gm37950"          "Igsf8"
#  [1447] "Atp1a2"           "Kcnj9"            "Gm36937"
#  [1450] "Kcnj10"           "Pigm"             "Slamf9"
#  [1453] "Igsf9"            "Tagln2"           "Cfap45"
#  [1456] "Vsig8"            "Slamf8"           "Fcrl6"
#  [1459] "Dusp23"           "Crp"              "Apcs"
#  [1462] "Olfr16"           "Olfr1408"         "Olfr1406"
#  [1465] "Olfr218"          "Olfr1404"         "Fcer1a"
#  [1468] "Olfr418"          "Mptx2"            "Ackr1"
#  [1471] "Cadm3"            "Aim2"             "Gm4955"
#  [1474] "BC094916"         "Pydc4"            "Pyhin1"
#  [1477] "Pydc3"            "AI607873"         "Ifi204"
#  [1480] "Mndal"            "Mnda"             "Ifi203"
#  [1483] "Ifi202b"          "Ifi205"           "Olfr433"
#  [1486] "Olfr432"          "Olfr430"          "Olfr429"
#  [1489] "Olfr427"          "Olfr231"          "Olfr424"
#  [1492] "Olfr420"          "Spta1"            "Olfr419"
#  [1495] "Mptx1"            "Olfr417"          "Olfr248"
#  [1498] "Olfr414"          "Olfr220"          "Fmn2"
#  [1501] "Grem2"            "Rgs7"             "Gm36307"
#  [1504] "Fh1"              "Kmo"              "Opn3"
#  [1507] "Chml"             "Wdr64"            "Exo1"
#  [1510] "Gm38100"          "Pld5"             "Rbm8a2"
#  [1513] "Gm38101"          "Gm36536"          "Cep170"
#  [1516] "Gm36992"          "Sdccag8"          "Gm15423"
#  [1519] "Akt3"             "Gm26801"          "Zbtb18"
#  [1522] "Gm37306"          "Gm37280"          "X2310043L19Rik"
#  [1525] "X1700016C15Rik"   "Adss"             "Gm16432"
#  [1528] "Desi2"            "B230369F24Rik"    "Cox20"
#  [1531] "Gm16586"          "Gm28062"          "Hnrnpu"
#  [1534] "Efcab2"           "Kif26b"           "Gm16564"
#  [1537] "Smyd3"            "Tfb2m"            "Cnst"
#  [1540] "Sccpdh"           "Gm1305"           "Ahctf1"
#  [1543] "Gm10518"          "Cdc42bpa"         "Adck3"
#  [1546] "Gm37336"          "Psen2"            "Gm31728"
#  [1549] "Itpkb"            "X6330403A02Rik"   "Gm37267"
#  [1552] "Parp1"            "Lin9"             "Mixl1"
#  [1555] "Acbd3"            "Gm37768"          "Gm38293"
#  [1558] "H3f3a"            "Gm17275"          "H3f3aos"
#  [1561] "Sde2"             "Lefty2"           "Pycr2"
#  [1564] "Lefty1"           "Tmem63a"          "X2210411M09Rik"
#  [1567] "Ephx1"            "X9130409I23Rik"   "Gm37406"
#  [1570] "Nvl"              "Cnih4"            "Wdr26"
#  [1573] "A430110L20Rik"    "Cnih3"            "Ccdc121"
#  [1576] "Dnah14"           "Lbr"              "Gm5533"
#  [1579] "Enah"             "Srp9"             "Vmn1r1"
#  [1582] "Degs1"            "X1700047M11Rik"   "Fbxo28"
#  [1585] "Trp53bp2"         "Capn2"            "Gm37885"
#  [1588] "Capn8"            "Gm37218"          "Ccdc185"
#  [1591] "Susd4"            "Tlr5"             "Gm38079"
#  [1594] "Disp1"            "Brox"             "Aida"
#  [1597] "Mia3"             "Taf1a"            "Gm37986"
#  [1600] "Hhipl2"           "Gm33973"          "Gm34068"
#  [1603] "Gm38108"          "Dusp10"           "X1700056E22Rik"
#  [1606] "Gm37223"          "Gm37712"          "X1700112H15Rik"
#  [1609] "Gm37800"          "X4930488B22Rik"   "Hlx"
#  [1612] "Gm34342"          "Marc1"            "Marc2"
#  [1615] "C130074G19Rik"    "Mark1"            "Gm38251"
#  [1618] "Gm34732"          "X4930433J02Rik"   "Gm37662"
#  [1621] "Rab3gap2"         "Gm34882"          "Iars2"
#  [1624] "X2010103J01Rik"   "Bpnt1"            "X4930532G15Rik"
#  [1627] "Eprs"             "X9630028B13Rik"   "Gm2061"
#  [1630] "Slc30a10"         "Gm38093"          "Lyplal1"
#  [1633] "Gm37134"          "A730004F24Rik"    "Tgfb2"
#  [1636] "Gm29491"          "Rrp15"            "A430105J06Rik"
#  [1639] "X1700023G09Rik"   "Gm37912"          "D1Pas1"
#  [1642] "Spata17"          "X1700007P06Rik"   "Gpatch2"
#  [1645] "Gm38155"          "Gm37896"          "Esrrg"
#  [1648] "Gm36388"          "X9330162B11Rik"   "Gm38064"
#  [1651] "Ush2a"            "Kctd3"            "Kcnk2"
#  [1654] "A430027H14Rik"    "Cenpf"            "Ptpn14"
#  [1657] "Gm26574"          "Gm37422"          "Smyd2"
#  [1660] "Prox1"            "Gm28172"          "Prox1os"
#  [1663] "Gm29678"          "Gm30725"          "Gm30932"
#  [1666] "Rps6kc1"          "Angel2"           "Vash2"
#  [1669] "Gm31373"          "Mfsd7b"           "A230020J21Rik"
#  [1672] "Spata45"          "Tatdn3"           "Nsl1"
#  [1675] "Gm38188"          "Batf3"            "Gm38161"
#  [1678] "Fam71a"           "Atf3"             "D730003I15Rik"
#  [1681] "Gm37168"          "Nenf"             "Tmem206"
#  [1684] "Ppp2r5a"          "Gm32200"          "Gm37432"
#  [1687] "Dtl"              "Ints7"            "Lpgat1"
#  [1690] "Gm38037"          "Nek2"             "X1700034H15Rik"
#  [1693] "Slc30a1"          "Rd3"              "Gm26670"
#  [1696] "Traf5"            "Gm26879"          "Rcor3"
#  [1699] "Gm10516"          "Kcnh1"            "Hhat"
#  [1702] "X1700065J18Rik"   "Sertad4"          "Gm15867"
#  [1705] "Syt14"            "Gm31406"          "Diexf"
#  [1708] "Irf6"             "A130010J15Rik"    "Traf3ip3"
#  [1711] "Gm15872"          "X4930570N18Rik"   "Lamb3"
#  [1714] "Hsd11b1"          "G0s2"             "Gm37650"
#  [1717] "Camk1g"           "X4631405K08Rik"   "X4930503O07Rik"
#  [1720] "Plxna2"           "Cd34"             "Gm16897"
#  [1723] "Gm32250"          "Gm37027"          "Cd46"
#  [1726] "Cr1l"             "Cr2"              "Fam171a1"
#  [1729] "Nmt2"             "Rpp38"            "Acbd7"
#  [1732] "Olah"             "Meig1"            "Dclre1c"
#  [1735] "Suv39h2"          "Gm13184"          "Hspa14"
#  [1738] "Cdnf"             "Fam107b"          "Gm13185"
#  [1741] "Gm13180"          "Gm13191"          "Frmd4a"
#  [1744] "X1700080N15Rik"   "Gm13189"          "Gm13175"
#  [1747] "Gm13179"          "Prpf18"           "Bend7"
#  [1750] "Sephs1"           "Phyh"             "Ucma"
#  [1753] "Mcm10"            "Optn"             "X4930551O13Rik"
#  [1756] "Gm26776"          "Ccdc3"            "Camk1d"
#  [1759] "Cdc123"           "Nudt5"            "Gm13199"
#  [1762] "Sec61a2"          "Gm13267"          "Dhtkd1"
#  [1765] "Upf2"             "Proser2"          "Gm10857"
#  [1768] "Echdc3"           "A230108P19Rik"    "Gm13383"
#  [1771] "Usp6nl"           "Gm13388"          "Gm13391"
#  [1774] "Celf2"            "Gm13389"          "Gm26565"
#  [1777] "Gm28641"          "Gm13211"          "X1700061F12Rik"
#  [1780] "Gm13219"          "Gm13218"          "Gata3"
#  [1783] "Gm13256"          "X4930412O13Rik"   "X9230102O04Rik"
#  [1786] "Gm13262"          "Taf3"             "Atp5c1"
#  [1789] "Kin"              "Itih2"            "Itih5"
#  [1792] "Sfmbt2"           "Gm13264"          "Prkcq"
#  [1795] "Gm38171"          "X8030442B05Rik"   "Gm13293"
#  [1798] "Gm13291"          "Pfkfb3"           "Gm10851"
#  [1801] "Rbm17"            "Gm17490"          "Il2ra"
#  [1804] "Il15ra"           "Fbxo18"           "Ankrd16"
#  [1807] "Itga8"            "E030013I19Rik"    "Fam188a"
#  [1810] "Gm37565"          "Pter"             "C1ql3"
#  [1813] "Rsu1"             "Cubn"             "Trdmt1"
#  [1816] "Vim"              "St8sia6"          "Gm37126"
#  [1819] "Hacd1"            "Stam"             "Tmem236"
#  [1822] "Mrc1"             "Slc39a12"         "Cacnb2"
#  [1825] "Gm10848"          "Gm13269"          "Nsun6"
#  [1828] "Arl5b"            "Malrd1"           "Plxdc2"
#  [1831] "Gm13322"          "Nebl"             "Gm13324"
#  [1834] "H2afb1"           "A930004D18Rik"    "Gm13330"
#  [1837] "Skida1"           "Mllt10"           "Dnajc1"
#  [1840] "Commd3"           "Bmi1"             "Spag6"
#  [1843] "Carlr"            "Pip4k2a"          "X4930426L09Rik"
#  [1846] "Armc3"            "X4930447M23Rik"   "Msrb2"
#  [1849] "Gm13344"          "Ptf1aos"          "Ptf1a"
#  [1852] "X4921504E06Rik"   "Gm13348"          "Otud1"
#  [1855] "Gm13346"          "Etl4"             "Gm17171"
#  [1858] "Gm13335"          "Gm13362"          "Arhgap21"
#  [1861] "Gm13375"          "Gm13376"          "Enkur"
#  [1864] "Thnsl1"           "Gm13327"          "Gpr158"
#  [1867] "Myo3a"            "Gad2"             "X1700092C17Rik"
#  [1870] "Apbb1ip"          "Pdss1"            "Abi1"
#  [1873] "Acbd5"            "Mastl"            "Yme1l1"
#  [1876] "X4931423N10Rik"   "Nxph2"            "Spopl"
#  [1879] "Hnmt"             "Tbpl2"            "Il1f8"
#  [1882] "Il1f9"            "Il1f6"            "Il1f5"
#  [1885] "Il1f10"           "Gm13411"          "Il1rn"
#  [1888] "Psd4"             "Pax8"             "Gm13417"
#  [1891] "Cacna1b"          "Ehmt1"            "Arrdc1"
#  [1894] "Zmynd19"          "Dph7"             "Mrpl41"
#  [1897] "Pnpla7"           "Nsmf"             "Entpd8"
#  [1900] "Noxa1"            "Gm13387"          "Nrarp"
#  [1903] "Gm38287"          "Tor4a"            "Nelfb"
#  [1906] "X4933433C11Rik"   "Fam166a"          "Tubb4b"
#  [1909] "Slc34a3"          "Rnf224"           "Cysrt1"
#  [1912] "Rnf208"           "Ndor1"            "Tmem203"
#  [1915] "Tprn"             "Ssna1"            "Anapc2"
#  [1918] "Tmem210"          "Lrrc26"           "Grin1"
#  [1921] "Grin1os"          "AA543186"         "Man1b1"
#  [1924] "Dpp7"             "Uap1l1"           "Sapcd2"
#  [1927] "Entpd2"           "Npdc1"            "Fut7"
#  [1930] "Abca2"            "BC029214"         "Clic3"
#  [1933] "Ptgds"            "Lcn12"            "C8g"
#  [1936] "Fbxw5"            "Traf2"            "Edf1"
#  [1939] "Mamdc4"           "Phpt1"            "Gm996"
#  [1942] "Gm26702"          "Rabl6"            "Fcnaos"
#  [1945] "Ccdc183"          "Tmem141"          "Fcna"
#  [1948] "Lcn8"             "Lcn5"             "Lcn6"
#  [1951] "Lcn10"            "Obp2a"            "A230005M16Rik"
#  [1954] "Bmyc"             "Obp2b"            "Lcn3"
#  [1957] "Lcn11"            "Gm13539"          "Glt6d1"
#  [1960] "Lcn9"             "Sohlh1"           "Kcnt1"
#  [1963] "Camsap1"          "Ubac1"            "Nacc2"
#  [1966] "Gm13554"          "C330006A16Rik"    "X1810012K08Rik"
#  [1969] "Gm13553"          "Lhx3"             "Gm27196"
#  [1972] "Qsox2"            "C030048H21Rik"    "Ccdc187"
#  [1975] "Gpsm1"            "Dnlz"             "Card9"
#  [1978] "Snapc4"           "Gm13563"          "Sdccag3"
#  [1981] "Pmpca"            "Inpp5e"           "Sec16a"
#  [1984] "Notch1"           "Egfl7"            "Gm20532"
#  [1987] "Agpat2"           "Fam69b"           "Snhg7os"
#  [1990] "Lcn4"             "Abo"              "Surf6"
#  [1993] "Med22"            "Rpl7a"            "Surf1"
#  [1996] "Surf2"            "Surf4"            "Stkld1"
#  [1999] "Rexo4"            "Adamts13"         "Cacfd1"
#  [2002] "Slc2a6"           "Gm13398"          "Tmem8c"
#  [2005] "Adamtsl2"         "Fam163b"          "Dbhos"
#  [2008] "Dbh"              "Sardh"            "Sardhos"
#  [2011] "Vav2"             "AA645442"         "Brd3"
#  [2014] "Wdr5"             "Rxra"             "Col5a1"
#  [2017] "Fcnb"             "Gm13371"          "F730016J06Rik"
#  [2020] "Olfm1"            "Gm13373"          "Ppp1r26"
#  [2023] "X1700007K13Rik"   "Mrps2"            "Gbgt1"
#  [2026] "Gm10134"          "Ralgds"           "Cel"
#  [2029] "Gm13381"          "Gtf3c5"           "Gfi1b"
#  [2032] "Tsc1"             "X1700026L06Rik"   "Ak8"
#  [2035] "Gtf3c4"           "Ddx31"            "Barhl1"
#  [2038] "Cfap77"           "Ttf1"             "Gm13393"
#  [2041] "Setx"             "Ntng2"            "Med27"
#  [2044] "Gm13402"          "Rapgef1"          "Gm13420"
#  [2047] "Gm13547"          "Trub2"            "Coq4"
#  [2050] "Slc27a4"          "Urm1"             "X2600006K01Rik"
#  [2053] "Cercam"           "Odf2"             "Gle1"
#  [2056] "Sptan1"           "Wdr34"            "Set"
#  [2059] "Pkn3"             "Zdhhc12"          "Zer1"
#  [2062] "Tbc1d13"          "Endog"            "D2Wsu81e"
#  [2065] "Ccbl1"            "X1700084E18Rik"   "Lrrc8a"
#  [2068] "Gm28035"          "Phyhd1"           "Gm28038"
#  [2071] "Dolk"             "Nup188"           "Sh3glb2"
#  [2074] "Fam73b"           "Dolpp1"           "Crat"
#  [2077] "Gm16323"          "Ppp2r4"           "Ier5l"
#  [2080] "Gm14487"          "Cstad"            "X9330198N18Rik"
#  [2083] "Gm14486"          "X1700001O22Rik"   "X4930527E20Rik"
#  [2086] "Ntmt1"            "Asb6"             "Prrx2"
#  [2089] "Ptges"            "Tor1b"            "Tor1a"
#  [2092] "BC005624"         "Usp20"            "Fnbp1"
#  [2095] "Gpr107"           "Gm13405"          "Ncs1"
#  [2098] "Hmcn2"            "Ass1"             "Fubp3"
#  [2101] "Gm13425"          "Prdm12"           "Exosc2"
#  [2104] "Gm13427"          "Abl1"             "Qrfp"
#  [2107] "Fibcd1"           "Gm13441"          "Lamc3"
#  [2110] "Aif1l"            "Gm13442"          "Nup214"
#  [2113] "Gm13609"          "Fam78a"           "Plpp7"
#  [2116] "Prrc2b"           "Gm13610"          "Pomt1"
#  [2119] "Uck1"             "Swi5"             "Golga2"
#  [2122] "Dnm1"             "Ciz1"             "X1110008P14Rik"
#  [2125] "Lcn2"             "Ptges2"           "Slc25a25"
#  [2128] "Naif1"            "Gm13412"          "Fam102a"
#  [2131] "Dpm2"             "X9430097D07Rik"   "Pip5kl1"
#  [2134] "St6galnac4"       "St6galnac6"       "Ak1"
#  [2137] "Eng"              "Fpgs"             "Cdk9"
#  [2140] "Sh2d3c"           "X6330409D20Rik"   "Ttc16"
#  [2143] "Tor2a"            "Ptrh1"            "Cfap157"
#  [2146] "Stxbp1"           "Gm13524"          "Gm13523"
#  [2149] "Fam129b"          "Lrsam1"           "Rpl12"
#  [2152] "Slc2a8"           "Garnl3"           "Ralgps1"
#  [2155] "Gm13528"          "Angptl2"          "Zbtb34"
#  [2158] "Gm13536"          "Zbtb43"           "Gm13530"
#  [2161] "Lmx1b"            "C130021I20Rik"    "X9430024E24Rik"
#  [2164] "Mvb12b"           "Nron"             "Gm13403"
#  [2167] "Gm13404"          "C230014O12Rik"    "Gm38389"
#  [2170] "Pbx3"             "C79798"           "Mapkap1"
#  [2173] "Gapvd1"           "Hspa5"            "Rabepk"
#  [2176] "Fbxw2"            "Psmd5"            "Cutal"
#  [2179] "Phf19"            "Traf1"            "Hc"
#  [2182] "Gm13449"          "AI182371"         "Cntrl"
#  [2185] "Rab14"            "Gm13605"          "Gsn"
#  [2188] "Stom"             "X4930568D16Rik"   "X4930402F06Rik"
#  [2191] "Ggta1"            "Gm35202"          "Dab2ip"
#  [2194] "Ttll11"           "X9030204H09Rik"   "Ndufa8"
#  [2197] "Morn5"            "Lhx6"             "Rbm18"
#  [2200] "Mrrf"             "Gm13431"          "Ptgs1"
#  [2203] "Olfr338"          "Olfr339"          "Olfr340"
#  [2206] "Olfr341"          "Olfr342"          "Olfr344"
#  [2209] "Olfr345"          "Olfr346"          "Olfr347"
#  [2212] "Olfr348"          "Olfr50"           "Olfr3"
# ...
# [27262] "Men1"             "Map4k2"           "Gm14966"
# [27265] "Sf1"              "Pygm"             "Rasgrp2"
# [27268] "Nrxn2"            "Gm14964"          "Slc22a12"
# [27271] "Gm14967"          "Gm14968"          "Rps6ka4"
# [27274] "Ccdc88b"          "Prdx5"            "Trmt112"
# [27277] "Esrra"            "Tex40"            "Kcnk4"
# [27280] "Gpr137"           "Bad"              "Plcb3"
# [27283] "Ppp1r14b"         "Fkbp2"            "Vegfb"
# [27286] "Dnajc4"           "Nudt22"           "Trpt1"
# [27289] "Fermt3"           "Stip1"            "Macrod1"
# [27292] "Flrt1"            "Otub1"            "Cox8a"
# [27295] "Naa40"            "Rcor2"            "Mark2"
# [27298] "Gm17227"          "AI846148"         "X1700105P06Rik"
# [27301] "X2700081O15Rik"   "Rtn3"             "Atl3"
# [27304] "Pla2g16"          "Lgals12"          "Hrasls5"
# [27307] "Slc22a19"         "Slc22a26"         "Slc22a27"
# [27310] "Slc22a28"         "Slc22a29"         "Slc22a30"
# [27313] "Slc22a8"          "Slc22a6"          "Chrm1"
# [27316] "Slc3a2"           "Wdr74"            "X1700092M07Rik"
# [27319] "Stx5a"            "Nxf1"             "Taf6l"
# [27322] "Polr2g"           "Zbtb3"            "Ttc9c"
# [27325] "Hnrnpul2"         "Gng3"             "Bscl2"
# [27328] "Lrrn4cl"          "Ubxn1"            "Uqcc3"
# [27331] "Lbhd1"            "X1810009A15Rik"   "Ints5"
# [27334] "Ganab"            "B3gat3"           "Rom1"
# [27337] "Eml3"             "Mta2"             "Tut1"
# [27340] "Eef1g"            "Ahnak"            "Scgb1a1"
# [27343] "Asrgl1"           "Pcna-ps2"         "Scgb2a2"
# [27346] "Incenp"           "Fth1"             "Best1"
# [27349] "Rab3il1"          "Fads3"            "Fads2"
# [27352] "Fads1"            "Fen1"             "Tmem258"
# [27355] "Myrf"             "Dagla"            "Syt7"
# [27358] "Gm26859"          "Lrrc10b"          "Ppp1r32"
# [27361] "Sdhaf2"           "Cpsf7"            "Tmem216"
# [27364] "Tmem138"          "Cyb561a3"         "Tkfc"
# [27367] "Ddb1"             "Vwce"             "Pga5"
# [27370] "Vps37c"           "Cd5"              "Cd6"
# [27373] "Slc15a3"          "Tmem132a"         "Tmem109"
# [27376] "Prpf19"           "Zp1"              "Ptgdr2"
# [27379] "Ccdc86"           "Ms4a10"           "Ms4a15"
# [27382] "Ms4a18"           "Gm28347"          "AW112010"
# [27385] "Ms4a8a"           "X1700017D01Rik"   "X1700025F22Rik"
# [27388] "Ms4a13"           "X4930526L06Rik"   "Ms4a12"
# [27391] "Ms4a1"            "Ms4a5"            "Ms4a14"
# [27394] "Ms4a7"            "Gm28935"          "Ms4a4a"
# [27397] "Ms4a4c"           "Ms4a4b"           "Gm37387"
# [27400] "Ms4a6c"           "Gm8369"           "Gm19261"
# [27403] "Ms4a6b"           "Ms4a4d"           "Ms4a6d"
# [27406] "Ms4a2"            "Ms4a3"            "Oosp2"
# [27409] "Oosp1"            "Oosp3"            "Gif"
# [27412] "Mrpl16"           "Stx3"             "Olfr1417"
# [27415] "Olfr1418"         "Olfr1419"         "Olfr1420"
# [27418] "Patl1"            "Osbp"             "Olfr1423"
# [27421] "Olfr1424"         "Olfr1425"         "Olfr1426"
# [27424] "Olfr1427"         "Olfr1428"         "Olfr76"
# [27427] "Olfr1555-ps1"     "Olfr1431"         "Olfr1432"
# [27430] "Olfr262"          "Olfr235"          "Olfr1434"
# [27433] "Olfr1436"         "Olfr1437"         "Olfr1438-ps1"
# [27436] "Olfr1440"         "Olfr1441"         "Pfpl"
# [27439] "Mpeg1"            "Dtx4"             "Fam111a"
# [27442] "Gm4952"           "Glyat"            "Olfr1442"
# [27445] "Olfr1443"         "Keg1"             "Gm15962"
# [27448] "Cntf"             "Zfp91"            "Lpxn"
# [27451] "Olfr1444"         "Olfr1445"         "Olfr1446"
# [27454] "Olfr1447"         "Olfr1448"         "RP24-84O13.6"
# [27457] "Olfr1449"         "Olfr1450"         "Olfr1451"
# [27460] "Olfr1453"         "Olfr1454"         "Olfr1457"
# [27463] "Olfr1458"         "Olfr1459"         "Olfr1461"
# [27466] "Olfr1462"         "Olfr1463"         "Olfr1465"
# [27469] "Olfr1466"         "Olfr1467"         "Olfr1469"
# [27472] "Olfr1471"         "Olfr1472"         "Olfr1474"
# [27475] "Olfr1475"         "Olfr1477"         "Olfr1480"
# [27478] "Olfr1484"         "Olfr1487"         "Olfr1489"
# [27481] "Olfr1490"         "Olfr1491"         "Olfr1493-ps1"
# [27484] "Olfr1494"         "Olfr1495"         "Olfr1496"
# [27487] "Olfr1496-1"       "Olfr1497"         "Olfr1499"
# [27490] "Olfr1500"         "Olfr1501"         "Olfr1502"
# [27493] "Olfr1504"         "Olfr1505"         "Tle4"
# [27496] "Psat1"            "Cep78"            "C130060C02Rik"
# [27499] "Gnaq"             "Gna14"            "Vps13a"
# [27502] "Foxb2"            "Prune2"           "Gcnt1"
# [27505] "Rfk"              "Pcsk5"            "Ostf1"
# [27508] "Nmrk1"            "Carnmt1"          "D030056L22Rik"
# [27511] "Trpm6"            "Rorb"             "Anxa1"
# [27514] "X1500015L24Rik"   "Aldh1a1"          "Aldh1a7"
# [27517] "Tmc1"             "Zfand5"           "Gda"
# [27520] "Gm3443"           "X1110059E24Rik"   "Abhd17b"
# [27523] "Tmem2"            "Trpm3"            "Gm27151"
# [27526] "C330002G04Rik"    "X2410080I02Rik"   "Klf9"
# [27529] "Smc5"             "Mamdc2"           "X1700028P14Rik"
# [27532] "Gm9493"           "Gm6563"           "Ptar1"
# [27535] "Gm9938"           "Apba1"            "Fam189a2"
# [27538] "X1700021P04Rik"   "Tjp2"             "Fxn"
# [27541] "Pip5k1b"          "Pip5k1bos"        "Fam122a"
# [27544] "Tmem252"          "Pgm5"             "Gm10053"
# [27547] "Foxd4"            "Cbwd1"            "Dock8"
# [27550] "Kank1"            "Dmrt1"            "Dmrt3"
# [27553] "X2610016A17Rik"   "Dmrt2"            "Smarca2"
# [27556] "Gm815"            "Vldlr"            "Kcnv2"
# [27559] "Pum3"             "Rfx3"             "Gm28228"
# [27562] "Glis3"            "D930032P07Rik"    "Slc1a1"
# [27565] "X4430402I18Rik"   "Plpp6"            "Cdc37l1"
# [27568] "Ak3"              "X1700018L02Rik"   "Rcl1"
# [27571] "Jak2"             "Insl6"            "Rln1"
# [27574] "Plgrkt"           "Cd274"            "Pdcd1lg2"
# [27577] "A930007I19Rik"    "Ric1"             "Ermp1"
# [27580] "Mlana"            "X9930021J03Rik"   "Ranbp6"
# [27583] "Il33"             "Trpd52l3"         "Uhrf2"
# [27586] "Gldc"             "Mbl2"             "Dkk1"
# [27589] "Prkg1"            "Cstf2t"           "A1cf"
# [27592] "Asah2"            "Sgms1"            "X2700046G09Rik"
# [27595] "Rpl9-ps6"         "Minpp1"           "Papss2"
# [27598] "Atad1"            "Pten"             "Rnls"
# [27601] "Gm7237"           "Gm8975"           "Lipo4"
# [27604] "Lipo1"            "Lipo2"            "Gm5097"
# [27607] "Gm5519"           "Lipf"             "Lipk"
# [27610] "Lipn"             "Lipm"             "Ankrd22"
# [27613] "Stambpl1"         "Acta2"            "Fas"
# [27616] "Ch25h"            "Gm26902"          "Lipa"
# [27619] "Ifit2"            "Ifit3"            "Ifit1bl1"
# [27622] "Ifit3b"           "Ifit1bl2"         "Ifit1"
# [27625] "Slc16a12"         "Pank1"            "Kif20b"
# [27628] "Gm5248"           "A830019P07Rik"    "Htr7"
# [27631] "Rpp30"            "Ankrd1"           "Pcgf5"
# [27634] "Hectd2"           "Ppp1r3c"          "Tnks2"
# [27637] "Fgfbp3"           "Btaf1"            "Cpeb3"
# [27640] "A330032B11Rik"    "March5"           "Ide"
# [27643] "Kif11"            "Hhex"             "Exoc6"
# [27646] "Cyp26c1"          "Cyp26a1"          "Myof"
# [27649] "I830134H01Rik"    "Cep55"            "Ffar4"
# [27652] "Rbp4"             "Pde6c"            "Fra10ac1"
# [27655] "Lgi1"             "Gm42723"          "Slc35g1"
# [27658] "Plce1"            "Gm28991"          "Noc3l"
# [27661] "Tbc1d12"          "Hells"            "Cyp2c55"
# [27664] "Cyp2c65"          "Cyp2c66"          "Cyp2c29"
# [27667] "Cyp2c38"          "Cyp2c39"          "Cyp2c67"
# [27670] "Cyp2c68"          "Cyp2c40"          "Cyp2c69"
# [27673] "Cyp2c37"          "Cyp2c54"          "Cyp2c50"
# [27676] "Cyp2c70"          "Pdlim1"           "Sorbs1"
# [27679] "Aldh18a1"         "Gm27042"          "Tctn3"
# [27682] "Entpd1"           "Cc2d2b"           "Ccnj"
# [27685] "E030044B06Rik"    "Zfp518a"          "Blnk"
# [27688] "Dntt"             "Opalin"           "Tll2"
# [27691] "Tm9sf3"           "Pik3ap1"          "Lcor"
# [27694] "Gm340"            "AI606181"         "Slit1"
# [27697] "Arhgap19"         "Frat2"            "Rrp12"
# [27700] "Pgam1"            "Exosc1"           "Zdhhc16"
# [27703] "Mms19"            "Ubtd1"            "Ankrd2"
# [27706] "Hoga1"            "X4933411K16Rik"   "Morn4"
# [27709] "Pi4k2a"           "Avpi1"            "Marveld1"
# [27712] "Zfyve27"          "Sfrp5"            "Golga7b"
# [27715] "Crtac1"           "R3hcc1l"          "Gm16541"
# [27718] "Loxl4"            "Pyroxd2"          "Hps1"
# [27721] "Hpse2"            "Cnnm1"            "Got1"
# [27724] "Gm20467"          "Nkx2-3"           "Slc25a28"
# [27727] "Entpd7"           "Cox15"            "Cutc"
# [27730] "Abcc2"            "Dnmbp"            "Cpn1"
# [27733] "Cyp2c44"          "Erlin1"           "Chuk"
# [27736] "Cwf19l1"          "Bloc1s2"          "Pkd2l1"
# [27739] "Scd3"             "Scd2"             "Scd4"
# [27742] "Scd1"             "Wnt8b"            "Sec31b"
# [27745] "Gm20538"          "Ndufb8"           "Hif1an"
# [27748] "Gm26644"          "Pax2"             "Gm20395"
# [27751] "X1700039E22Rik"   "Fam178a"          "Sema4g"
# [27754] "Mrpl43"           "Peo1"             "Lzts2"
# [27757] "Pdzd7"            "Sfxn3"            "Kazald1"
# [27760] "Tlx1"             "Tlx1os"           "Lbx1"
# [27763] "Gm29595"          "Gm29593"          "Gm29594"
# [27766] "Gm28578"          "Btrc"             "Poll"
# [27769] "Dpcd"             "Fbxw4"            "Fgf8"
# [27772] "Npm3"             "Gm15491"          "Mgea5"
# [27775] "Kcnip2"           "X9130011E15Rik"   "X4930505N22Rik"
# [27778] "Hps6"             "Ldb1"             "Pprc1"
# [27781] "Nolc1"            "Elovl3"           "Pitx3"
# [27784] "Gbf1"             "Nfkb2"            "Psd"
# [27787] "Fbxl15"           "Cuedc2"           "Gm26792"
# [27790] "Tmem180"          "Actr1a"           "Sufu"
# [27793] "Trim8"            "Arl3"             "Sfxn2"
# [27796] "Wbp1l"            "Cyp17a1"          "Borcs7"
# [27799] "As3mt"            "Cnnm2"            "Nt5c2"
# [27802] "Ina"              "Pcgf6"            "Taf5"
# [27805] "Usmg5"            "Pdcd11"           "Calhm2"
# [27808] "Calhm1"           "Calhm3"           "Gm6970"
# [27811] "Neurl1a"          "Sh3pxd2a"         "Obfc1"
# [27814] "Gm19557"          "Slk"              "Gm16068"
# [27817] "Col17a1"          "Sfr1"             "Cfap43"
# [27820] "Gsto1"            "Gsto2"            "Cfap58"
# [27823] "Sorcs3"           "Rpl13a-ps1"       "Sorcs1"
# [27826] "Gm26629"          "Ins1"             "Xpnpep1"
# [27829] "X1700054A03Rik"   "Add3"             "Mxi1"
# [27832] "Gm10197"          "Smndc1"           "Mirt1"
# [27835] "X4833407H14Rik"   "Dusp5"            "Nutf2-ps1"
# [27838] "Smc3"             "Rbm20"            "Gm16299"
# [27841] "Pdcd4"            "Bbip1"            "Shoc2"
# [27844] "Adra2a"           "Gpam"             "Tectb"
# [27847] "Gucy2g"           "Acsl5"            "Zdhhc6"
# [27850] "Vti1a"            "X4930552P12Rik"   "Tcf7l2"
# [27853] "Habp2"            "Nrap"             "Gm17197"
# [27856] "Casp7"            "Plekhs1"          "Dclre1a"
# [27859] "Nhlrc2"           "Adrb1"            "Ccdc186"
# [27862] "Tdrd1"            "Vwa2"             "Afap1l2"
# [27865] "Ablim1"           "B230217O12Rik"    "Fam160b1"
# [27868] "Trub1"            "Gm26874"          "Atrnl1"
# [27871] "Gm16277"          "Gfra1"            "Ccdc172"
# [27874] "X1810007D17Rik"   "Pnlip"            "Pnliprp1"
# [27877] "Pnliprp2"         "X1700019N19Rik"   "Hspa12a"
# [27880] "Eno4"             "Shtn1"            "Vax1"
# [27883] "Kcnk18"           "Gm29261"          "Slc18a2"
# [27886] "Pdzd8"            "Rps12-ps3"        "Emx2os"
# [27889] "Emx2"             "X2700089I24Rik"   "Gm17203"
# [27892] "Rab11fip2"        "E330013P04Rik"    "Fam204a"
# [27895] "Gm28351"          "Prlhr"            "Cacul1"
# [27898] "Nanos1"           "Eif3a"            "Fam45a"
# [27901] "Sfxn4"            "Prdx3"            "Grk5"
# [27904] "Zfp950"           "Gm7102"           "Gm6020"
# [27907] "Csf2ra"           "Gm21060"          "mt-Nd1"
# [27910] "mt-Nd2"           "mt-Co1"           "mt-Co2"
# [27913] "mt-Atp8"          "mt-Atp6"          "mt-Co3"
# [27916] "mt-Nd3"           "mt-Nd4l"          "mt-Nd4"
# [27919] "mt-Nd5"           "mt-Nd6"           "mt-Cytb"
# [27922] "AC123873-3"       "AC123873-1"       "AC123873-2"
# [27925] "AC126035-1"       "Gm16367"          "AC163611-1"
# [27928] "AC163611-2"       "AC140365-1"       "AC124606-2"
# [27931] "AC124606-1"       "AC133095-2"       "AC133095-1"
# [27934] "Vamp7"            "CAAA01165726-1"   "Spry3"
# [27937] "Tmlhe"            "AC133103-4"       "AC133103-6"
# [27940] "AC133103-7"       "AC133103-5"       "AC133103-1"
# [27943] "AC133103-3"       "Ccl21c"           "AC087559-3"
# [27946] "Fam205a2-1"       "AC087559-2"       "Ccl21b-1"
# [27949] "Il11ra2-1"        "Ccl27a-1"         "CR974586-3"
# [27952] "Ccl21c-1"         "CR974586-4"       "CR974586-6"
# [27955] "CR974586-5"       "CR974586-2"       "CR974586-1"
# [27958] "AC132444-1"       "AC132444-3"       "AC132444-5"
# [27961] "AC132444-4"       "AC132444-2"       "Csprs"
# [27964] "AC132444-6"       "AC165294-1"       "AC165294-2"
# [27967] "AC165294-3"       "AC164084-2"       "AC164084-3"
# [27970] "AC164084-1"       "AC140325-2"       "AC140325-1"
# [27973] "Gm3286-1"         "AC140325-3"       "AC140325-4"
# [27976] "Ccl27a-2"         "Il11ra2-2"        "Ccl19-1"
# [27979] "Ccl21a-1"         "Gm10931"          "CT868723-1"
# [27982] "AC125178-1"       "AC125178-3"       "AC125178-2"
# [27985] "Vmn1r186"         "AC102264-1"       "AC125149-3"
# [27988] "AC125149-5"       "AC125149-1"       "AC125149-2"
# [27991] "AC125149-4"       "AC234645-1"       "AC168977-2"
# [27994] "AC168977-1"       "PISD"             "DHRSX"
# [27997] "Vmn2r122"         "CAAA01147332-1"

# %%
rownames(expression_by_cluster$RNA) = new_var

# %%
for (entry in as.vector(scores['gene'])){
    if ('Nkx2.1' == entry){
        print(entry)
    }
}
# Out:
# Warning message in if ("Nkx2.1" == entry) {:
# “the condition has length > 1 and only the first element will be used”

# %%
scores[scores['gene']=='Nkx2-1',]
# Out:
#   gene   degree_all degree_in degree_out clustering_coefficient
# 1 Nkx2-1 92          4        88         0.01505017
# 2 Nkx2-1 10         10         0         0.28888889
# 3 Nkx2-1 64          7        57         0.04365079
# 4 Nkx2-1 64         13        51         0.06746032
# 5 Nkx2-1  7          7         0         0.14285714
# 6 Nkx2-1 64          4        60         0.02678571
#   clustering_coefficient_weighted degree_centrality_all degree_centrality_in
# 1 0.01647838                      0.025662483           0.0011157601
# 2 0.31915010                      0.001853568           0.0018535681
# 3 0.05088298                      0.013375131           0.0014629049
# 4 0.11837001                      0.010654237           0.0021641418
# 5 0.13070198                      0.001561106           0.0015611062
# 6 0.05293994                      0.015044664           0.0009402915
#   degree_centrality_out betweenness_centrality ⋯ assortative_coefficient
# 1 0.024546722           1654                   ⋯ -0.2787503
# 2 0.000000000              0                   ⋯ -0.2556780
# 3 0.011912226            988                   ⋯ -0.0943364
# 4 0.008490095           1448                   ⋯ -0.2015887
# 5 0.000000000              0                   ⋯ -0.1907596
# 6 0.014104372            361                   ⋯ -0.1746149
#   average_path_length community_random_walk module connectivity participation
# 1 3.504223            13                    1      4.59727686   0.3353025
# 2 2.714330             1                    3      0.03546159   0.6800000
# 3 2.859716             9                    1      1.91943325   0.6020508
# 4 2.724020             8                    2      1.09892285   0.6215820
# 5 2.649655             2                    0      0.06886374   0.5714286
# 6 2.280680             1                    1      1.73120129   0.4785156
#   role          cluster expression_specificity
# 1 Connector Hub 12       85.75037
# 2 Connector     15       20.80914
# 3 Peripheral    17      107.32699
# 4 Connector     22      579.43271
# 5 Peripheral    24       31.18209
# 6 Peripheral    27      518.07309
#   betweenness_centrality_normalized
# 1 2.2296113
# 2 0.0000000
# 3 1.3318355
# 4 1.9519209
# 5 0.0000000
# 6 0.4866322

# %%
remove(cluster)
# Out:
# Warning message in remove(cluster):
# “object 'cluster' not found”

# %%
scores = read.csv("scores_unnormalized.csv", stringsAsFactors = F)
colnames(scores)[[1]] = "gene"

get_specificity = function(gene, cluster){
  expression_by_cluster$RNA[gene, as.character(cluster)] / median(unlist(expression_by_cluster$RNA[gene,]))
}


# clusters_use = c(9,2,22,12,8) 
#clusters_use = c(22) 

scores %<>% dplyr::mutate(expression_specificity = mapply(get_specificity, gene, cluster))
scores$expression_specificity[is.nan(scores$expression_specificity)] = 0
scores$expression_specificity %<>% pmin(1000)
scores %<>%
  dplyr::group_by(gene) %>%
  dplyr::mutate(betweenness_centrality_normalized = betweenness_centrality/mean(betweenness_centrality)) %>%
  #dplyr::mutate(betweenness_centrality_normalized = betweenness_centrality) %>%
  dplyr::ungroup()




for (clusters_use in c(26,4,12,22)){
#get_specificity("Foxn1", 4)

top_regulators = scores %>% 
  subset(cluster %in% clusters_use) %>% 
  subset(expression_specificity>=5) %>% 
  dplyr::group_by(cluster) %>%
  dplyr::top_n(betweenness_centrality_normalized, n=20) 
p = scores %>%
  subset(cluster %in% clusters_use) %>% 
  ggplot(aes(x = expression_specificity, 
             y = betweenness_centrality_normalized,
             colour = as.character(cluster),
             fill = as.character(cluster), 
             label = gene)) + 
  scale_y_continuous(trans = "log1p") + 
  scale_x_continuous(trans = "log1p") + 
  ggtitle("Top regulators by cluster") + 
  geom_point() + 
  # ggrepel::geom_text_repel(data = top_regulators,color='black',max.overlaps = Inf) + 
  scale_fill_manual(values = fig1_colors) +
  scale_colour_manual(values = fig1_colors) +
  facet_grid(~cluster) + 
  ggsave(file.path(results_path, paste(clusters_use,"Norm_bet_cen_vs_rna_expr.png",sep='_')), width = 6, height = 4)  

}
# Out:
# Warning message:
# “Removed 4364 rows containing missing values (geom_point).”
# Warning message:
# “Removed 4899 rows containing missing values (geom_point).”
# Warning message:
# “Removed 3453 rows containing missing values (geom_point).”
# Warning message:
# “Removed 5858 rows containing missing values (geom_point).”

# %%
scores = read.csv("scores_unnormalized.csv", stringsAsFactors = F)
colnames(scores)[[1]] = "gene"

get_specificity = function(gene, cluster){
  expression_by_cluster$RNA[gene, as.character(cluster)] / median(unlist(expression_by_cluster$RNA[gene,]))
}


# clusters_use = c(9,2,22,12,8) 
for (clust in c(9,2,22,12,8) ){
print(clust)
# get_specificity("Foxn1", 4)
scores %<>% dplyr::mutate(expression_specificity = mapply(get_specificity, gene, clust))
scores$expression_specificity[is.nan(scores$expression_specificity)] = 0
scores$expression_specificity %<>% pmin(1000)
scores %<>%
  dplyr::group_by(gene) %>%
  dplyr::mutate(betweenness_centrality_normalized = betweenness_centrality/mean(betweenness_centrality)) %>%
  #dplyr::mutate(betweenness_centrality_normalized = betweenness_centrality) %>%
  dplyr::ungroup()

top_regulators = scores %>% 
  subset(cluster %in% clust) %>% 
  subset(expression_specificity>=5) %>% 
  dplyr::group_by(cluster) %>%
  dplyr::top_n(betweenness_centrality_normalized, n=20) 
p = scores %>%
  subset(cluster %in% clust) %>% 
  ggplot(aes(x = expression_specificity, 
             y = betweenness_centrality_normalized,
             colour = as.character(cluster),
             fill = as.character(cluster), 
             label = gene)) + 
  scale_y_continuous(trans = "log1p") + 
  scale_x_continuous(trans = "log1p") + 
  ggtitle("Top regulators by cluster") + 
  geom_point() + 
  ggrepel::geom_text_repel(data = top_regulators,color='black',max.overlaps = Inf) + 
  scale_fill_manual(values = fig1_colors) +
  scale_colour_manual(values = fig1_colors) +
  facet_grid(~cluster) + 
  ggsave(file.path(results_path, paste(cluster,"Norm_bet_cen_vs_rna_expr.pdf",sep='_')), width = 6, height = 4)  

    }
