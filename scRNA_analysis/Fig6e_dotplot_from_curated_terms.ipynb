# %%
ko_het = read.csv("ko_vs_het_final_20_terms.csv")

# %%
ko_het
# Out:
#    X   database
# 1   31 GO_Biological_Process_2021
# 2   34 GO_Biological_Process_2021
# 3   40 GO_Biological_Process_2021
# 4   53 Reactome_2016
# 5   60 Reactome_2016
# 6   65 KEGG_2019_Mouse
# 7   67 KEGG_2019_Mouse
# 8   81 WikiPathway_2021_Human
# 9   82 WikiPathway_2021_Human
# 10  83 WikiPathway_2021_Human
# 11  84 WikiPathway_2021_Human
# 12  85 WikiPathway_2021_Human
# 13  87 WikiPathway_2021_Human
# 14  90 WikiPathway_2021_Human
# 15 101 MSigDB_Hallmark_2020
# 16 103 MSigDB_Hallmark_2020
# 17 106 MSigDB_Hallmark_2020
# 18 107 MSigDB_Hallmark_2020
# 19 108 MSigDB_Hallmark_2020
# 20 110 MSigDB_Hallmark_2020
#    Term
# 1  regulation of cell population proliferation (GO:0042127)
# 2  branching morphogenesis of an epithelial tube (GO:0048754)
# 3  regulation of cell migration (GO:0030334)
# 4  Extracellular matrix organization Homo sapiens R-HSA-1474244
# 5  Degradation of the extracellular matrix Homo sapiens R-HSA-1474228
# 6  MAPK signaling pathway
# ...

# %%
library(enrichplot)

# %%
require(ggplot2)
library(scales)

# %%
ggdata <- ko_het

# %%
ggdata$neglog10qval = -ggdata$log10_qval

# %%
library(dplyr)

# %%
ggdata
# Out:
#    X   database
# 1   31 GO_Biological_Process_2021
# 2   34 GO_Biological_Process_2021
# 3   40 GO_Biological_Process_2021
# 4   53 Reactome_2016
# 5   60 Reactome_2016
# 6   65 KEGG_2019_Mouse
# 7   67 KEGG_2019_Mouse
# 8   81 WikiPathway_2021_Human
# 9   82 WikiPathway_2021_Human
# 10  83 WikiPathway_2021_Human
# 11  84 WikiPathway_2021_Human
# 12  85 WikiPathway_2021_Human
# 13  87 WikiPathway_2021_Human
# 14  90 WikiPathway_2021_Human
# 15 101 MSigDB_Hallmark_2020
# 16 103 MSigDB_Hallmark_2020
# 17 106 MSigDB_Hallmark_2020
# 18 107 MSigDB_Hallmark_2020
# 19 108 MSigDB_Hallmark_2020
# 20 110 MSigDB_Hallmark_2020
#    Term
# 1  regulation of cell population proliferation (GO:0042127)
# 2  branching morphogenesis of an epithelial tube (GO:0048754)
# 3  regulation of cell migration (GO:0030334)
# 4  Extracellular matrix organization Homo sapiens R-HSA-1474244
# 5  Degradation of the extracellular matrix Homo sapiens R-HSA-1474228
# 6  MAPK signaling pathway
# ...

# %%
ggdata$NumberOfGenes = ggdata$Count

# %%
library(viridis)

# %%
# total_genes = 753
# ntop <- 30
 # goEnrichment[1:ntop,]
ggdata = ggdata[order(-ggdata$neglog10qval),] 
ggdata$Term <- factor(ggdata$Term, levels = rev(ggdata$Term)) # fixes order
gg1 <- ggplot(ggdata,
  aes(x = Term, y = neglog10qval, size = NumberOfGenes, fill = GeneRatio))  +

  # expand_limits(y = 1) +
  geom_point(shape = 21) +
  scale_size(range = c(2.5,12.5)) +
  scale_fill_viridis() + 
  # scale_fill_continuous(low = 'royalblue', high = 'red4') +

  xlab('') + ylab('neglog10qval') +
  labs(
    title = 'EnrichR Terms',
    subtitle = 'Curated 20 terms ordered by -log10qval'
    )  +   

theme_bw(base_size = 24) +
  theme(
    legend.position = 'right',
    legend.background = element_rect(),
    plot.title = element_text(angle = 0, size = 16, face = 'bold', vjust = 1),
    plot.subtitle = element_text(angle = 0, size = 14, face = 'bold', vjust = 1),
    plot.caption = element_text(angle = 0, size = 12, face = 'bold', vjust = 1),

    axis.text.x = element_text(angle = 0, size = 12, face = 'bold', hjust = 1.10),
    axis.text.y = element_text(angle = 0, size = 12, face = 'bold', vjust = 0.5),
    axis.title = element_text(size = 12, face = 'bold'),
    axis.title.x = element_text(size = 12, face = 'bold'),
    axis.title.y = element_text(size = 12, face = 'bold'),
    axis.line = element_line(colour = 'black'),

    #Legend
    legend.key = element_blank(), # removes the border
    legend.key.size = unit(1, "cm"), # Sets overall area/size of the legend
    legend.text = element_text(size = 14, face = "bold"), # Text size
    title = element_text(size = 14, face = "bold")) +


coord_flip()

# %%
gg1
# Out:
# plot without title

# %%
ggsave("ko_vs_het.pdf",gg1, width = 15,
  height = 10)

# %%
ggsave("ko_vs_het.pdf",gg1, width = 15,
  height = 9)
